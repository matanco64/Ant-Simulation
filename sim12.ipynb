# %%
# 6 strategies, used StraightForceToColony to see if results are different

# adding ApplyColonyPullingForce() to informed as 5 but more runs
# run on maze more time than 7 200 ants detchafter 4f to 10f 	float colonyPullStrength = 4.0f

#changes strategies 0  is always on 
#checking wich combination is the best
# Map 4

# %%
from sim_tools import run_simulation, SimulationParameters
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

# %%
num_sim = 10
steering_strategies = 6

use_pher = [i for i in range(steering_strategies*num_sim)]

batch_results2 = [(run_simulation(SimulationParameters(usePheromoneSteering=pher % steering_strategies), headless=True), pher % steering_strategies)
                 for pher in tqdm(use_pher)]
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# 100%|██████████| 60/60 [36:39<00:00, 36.66s/it]

# %%
Steering_names = [
    "home",
    "circle",
    "gradient",
    "gaussian",
    "Inverse Square",
    "Exponential",
]

# %%
def plot_success_rates(batch_results, num_strategies=6, strategy_names=None):
    # Count successes for each strategy
    success_counts = [0] * num_strategies
    total_counts = [0] * num_strategies

    for res, strategy in batch_results:
        if 0 <= strategy < num_strategies:
            total_counts[strategy] += 1
            if res and getattr(res, "didSucceed", False):
                success_counts[strategy] += 1

    # Calculate success rates
    success_rates = [
        (success_counts[i] / total_counts[i]) if total_counts[i] else 0
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), success_rates,
            tick_label=labels, color='skyblue')
    plt.ylabel("Success Rate")
    plt.title("Success Rate by Steering Strategy")
    plt.ylim(0, 1)
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Success Rate={success_rates[i]:.2%} ({success_counts[i]}/{total_counts[i]})")


plot_success_rates(batch_results2, steering_strategies, Steering_names)
# Out:
# home: Success Rate=100.00% (10/10)
# circle: Success Rate=70.00% (7/10)
# gradient: Success Rate=70.00% (7/10)
# gaussian: Success Rate=80.00% (8/10)
# Inverse Square: Success Rate=30.00% (3/10)
# Exponential: Success Rate=100.00% (10/10)

# %%
# print results
def print_results(batch_results):
    for res, ss in batch_results:
        if res:
            print(
                f"Run (usePheromoneSteering={ss}): Success, duration={res.duration}, success={res.didSucceed}")
        else:
            print(f"Run (usePheromoneSteering={ss}): Failed")

# %%
print_results(batch_results2)
# Out:
# Run (usePheromoneSteering=0): Success, duration=268.2292785644531, success=True
# Run (usePheromoneSteering=1): Success, duration=543.867919921875, success=True
# Run (usePheromoneSteering=2): Success, duration=641.789794921875, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.3017578125, success=False
# Run (usePheromoneSteering=4): Success, duration=5000.2978515625, success=False
# Run (usePheromoneSteering=5): Success, duration=336.74676513671875, success=True
# Run (usePheromoneSteering=0): Success, duration=193.3451690673828, success=True
# Run (usePheromoneSteering=1): Success, duration=226.59303283691406, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.08056640625, success=False
# Run (usePheromoneSteering=3): Success, duration=197.49917602539062, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.04248046875, success=False
# Run (usePheromoneSteering=5): Success, duration=1906.5750732421875, success=True
# Run (usePheromoneSteering=0): Success, duration=263.0043029785156, success=True
# Run (usePheromoneSteering=1): Success, duration=234.69326782226562, success=True
# Run (usePheromoneSteering=2): Success, duration=547.5748901367188, success=True
# Run (usePheromoneSteering=3): Success, duration=266.0538635253906, success=True
# Run (usePheromoneSteering=4): Success, duration=249.98489379882812, success=True
# Run (usePheromoneSteering=5): Success, duration=254.3833770751953, success=True
# Run (usePheromoneSteering=0): Success, duration=228.0550079345703, success=True
# Run (usePheromoneSteering=1): Success, duration=5000.1142578125, success=False
# Run (usePheromoneSteering=2): Success, duration=5000.20849609375, success=False
# Run (usePheromoneSteering=3): Success, duration=280.3797912597656, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.150390625, success=False
# Run (usePheromoneSteering=5): Success, duration=427.7819519042969, success=True
# Run (usePheromoneSteering=0): Success, duration=279.9433898925781, success=True
# Run (usePheromoneSteering=1): Success, duration=5000.478515625, success=False
# Run (usePheromoneSteering=2): Success, duration=269.7088317871094, success=True
# Run (usePheromoneSteering=3): Success, duration=1542.126953125, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.3330078125, success=False
# Run (usePheromoneSteering=5): Success, duration=716.1657104492188, success=True
# Run (usePheromoneSteering=0): Success, duration=336.87908935546875, success=True
# Run (usePheromoneSteering=1): Success, duration=376.9005126953125, success=True
# Run (usePheromoneSteering=2): Success, duration=374.93060302734375, success=True
# Run (usePheromoneSteering=3): Success, duration=228.0749969482422, success=True
# Run (usePheromoneSteering=4): Success, duration=2376.052490234375, success=True
# Run (usePheromoneSteering=5): Success, duration=2724.282958984375, success=True
# Run (usePheromoneSteering=0): Success, duration=229.85662841796875, success=True
# Run (usePheromoneSteering=1): Success, duration=5000.224609375, success=False
# Run (usePheromoneSteering=2): Success, duration=252.80093383789062, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.23974609375, success=False
# Run (usePheromoneSteering=4): Success, duration=5000.1015625, success=False
# Run (usePheromoneSteering=5): Success, duration=191.17303466796875, success=True
# Run (usePheromoneSteering=0): Success, duration=387.013427734375, success=True
# Run (usePheromoneSteering=1): Success, duration=4061.114990234375, success=True
# Run (usePheromoneSteering=2): Success, duration=1339.7587890625, success=True
# Run (usePheromoneSteering=3): Success, duration=2143.5478515625, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.0751953125, success=False
# Run (usePheromoneSteering=5): Success, duration=222.63510131835938, success=True
# Run (usePheromoneSteering=0): Success, duration=228.90530395507812, success=True
# Run (usePheromoneSteering=1): Success, duration=197.39756774902344, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.28662109375, success=False
# Run (usePheromoneSteering=3): Success, duration=306.3570251464844, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.3095703125, success=False
# Run (usePheromoneSteering=5): Success, duration=225.5542755126953, success=True
# Run (usePheromoneSteering=0): Success, duration=264.0486755371094, success=True
# Run (usePheromoneSteering=1): Success, duration=246.93881225585938, success=True
# Run (usePheromoneSteering=2): Success, duration=3456.59521484375, success=True
# Run (usePheromoneSteering=3): Success, duration=600.6918334960938, success=True
# Run (usePheromoneSteering=4): Success, duration=219.5061492919922, success=True
# Run (usePheromoneSteering=5): Success, duration=273.4813537597656, success=True

# %%
import matplotlib.pyplot as plt


def plot_torus_positions_by_strategy(batch_results, strategy_names=None):
    """
    Plots the torus positions for each strategy in separate graphs.
    Each plot shows the paths for all successful runs of that strategy.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    if strategy_names is None:
        strategy_names = [f"Steering={i}" for i in range(num_strategies)]

    for strategy in range(num_strategies):
        # Collect all successful torus positions for this strategy
        paths = [
            res.torusPositions for res, pher in batch_results
            if pher == strategy and res and hasattr(res, "torusPositions") and res.didSucceed
        ]
        if not paths:
            continue  # Skip if no successful runs

        plt.figure(figsize=(6, 6))
        for path in paths:
            xs = [p.x for p in path]
            ys = [p.y for p in path]
            plt.plot(xs, ys, alpha=0.5)
        plt.title(f"Torus Paths - {strategy_names[strategy]}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.grid(True)
        plt.axis("equal")
        plt.show()

# %%
plot_torus_positions_by_strategy(batch_results2, Steering_names)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_duration_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the durations (time to win) for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect durations for each strategy
    durations_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False):
            durations_by_strategy[strategy].append(res.duration)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(durations_by_strategy, tick_labels=labels)
    plt.ylabel("Duration (seconds)")
    plt.title("Time to Win by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average duration for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            durations_by_strategy[i]) if durations_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Duration = {avg:.2f} seconds")

# Example usage:

# %%
plot_duration_comparison(batch_results2, Steering_names)
# Out:
# home: Average Duration = 267.93 seconds
# circle: Average Duration = 841.07 seconds
# gradient: Average Duration = 983.31 seconds
# gaussian: Average Duration = 695.59 seconds
# Inverse Square: Average Duration = 948.51 seconds
# Exponential: Average Duration = 727.88 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np


def compute_path_length(points):
    """Compute total path length from a list of Point objects with x, y attributes."""
    if not points or len(points) < 2:
        return 0
    return sum(
        np.linalg.norm([points[i+1].x - points[i].x,
                       points[i+1].y - points[i].y])
        for i in range(len(points)-1)
    )


def plot_path_length_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the total path length for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect path lengths for each strategy
    path_lengths_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False) and hasattr(res, "torusPositions"):
            path_length = compute_path_length(res.torusPositions)
            path_lengths_by_strategy[strategy].append(path_length)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(path_lengths_by_strategy, tick_labels=labels)
    plt.ylabel("Total Path Length")
    plt.title("Torus Path Length by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average path length for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            path_lengths_by_strategy[i]) if path_lengths_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Path Length = {avg:.2f}")

# Example usage:

# %%
plot_path_length_comparison(batch_results2, Steering_names)
# Out:
# home: Average Path Length = 160.56
# circle: Average Path Length = 689.65
# gradient: Average Path Length = 998.20
# gaussian: Average Path Length = 580.12
# Inverse Square: Average Path Length = 714.35
# Exponential: Average Path Length = 644.73

# %%
import numpy as np
import matplotlib.pyplot as plt


def compute_average_turning_angle(points):
    """Compute the average turning angle (in degrees) for a path of Point objects."""
    if not points or len(points) < 3:
        return 0
    angles = []
    for i in range(1, len(points)-1):
        v1 = np.array([points[i].x - points[i-1].x,
                      points[i].y - points[i-1].y])
        v2 = np.array([points[i+1].x - points[i].x,
                      points[i+1].y - points[i].y])
        if np.linalg.norm(v1) == 0 or np.linalg.norm(v2) == 0:
            continue
        cos_angle = np.clip(
            np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)), -1, 1)
        angle = np.arccos(cos_angle)
        angles.append(np.degrees(angle))
    return np.mean(angles) if angles else 0


def plot_smoothness_comparison(batch_results, strategy_names=None):
    """
    Plots a bar chart comparing the average turning angle (smoothness) for each strategy.
    Only successful runs are included.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    smoothness_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False) and hasattr(res, "torusPositions"):
            avg_angle = compute_average_turning_angle(res.torusPositions)
            smoothness_by_strategy[strategy].append(avg_angle)

    # Compute mean smoothness for each strategy
    mean_smoothness = [
        np.mean(smoothness_by_strategy[i]) if smoothness_by_strategy[i] else float(
            'nan')
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), mean_smoothness,
            tick_label=labels, color='purple')
    plt.ylabel("Average Turning Angle (degrees)")
    plt.title("Route Smoothness by Strategy (Lower is Smoother)")
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Average Turning Angle = {mean_smoothness[i]:.2f}°")

# Example usage:
plot_smoothness_comparison(batch_results2, Steering_names)
# Out:
# home: Average Turning Angle = 115.44°
# circle: Average Turning Angle = 126.02°
# gradient: Average Turning Angle = 137.12°
# gaussian: Average Turning Angle = 129.34°
# Inverse Square: Average Turning Angle = 127.81°
# Exponential: Average Turning Angle = 127.44°
