# %%
# 6 strategies, used StraightForceToColony to see if results are different

# adding ApplyColonyPullingForce() to informed as 5 but more runs
# run on maze more time than 7 200 ants detchafter 4f to 10f 	float colonyPullStrength = 4.0f

#same as 8 but more runs

# %%
from sim_tools import run_simulation, SimulationParameters
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

# %%
num_sim = 6
steering_strategies = 6

use_pher = [i for i in range(steering_strategies*num_sim)]

batch_results2 = [(run_simulation(SimulationParameters(usePheromoneSteering=pher % steering_strategies), headless=True), pher % steering_strategies)
                 for pher in tqdm(use_pher)]
# Out:
# 100%|██████████| 36/36 [1:37:47<00:00, 162.99s/it]

# %%
Steering_names = [
    "home",
    "circle",
    "gradient",
    "gaussian",
    "Inverse Square",
    "Exponential",
]

# %%
def plot_success_rates(batch_results, num_strategies=6, strategy_names=None):
    # Count successes for each strategy
    success_counts = [0] * num_strategies
    total_counts = [0] * num_strategies

    for res, strategy in batch_results:
        if 0 <= strategy < num_strategies:
            total_counts[strategy] += 1
            if res and getattr(res, "didSucceed", False):
                success_counts[strategy] += 1

    # Calculate success rates
    success_rates = [
        (success_counts[i] / total_counts[i]) if total_counts[i] else 0
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), success_rates,
            tick_label=labels, color='skyblue')
    plt.ylabel("Success Rate")
    plt.title("Success Rate by Steering Strategy")
    plt.ylim(0, 1)
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Success Rate={success_rates[i]:.2%} ({success_counts[i]}/{total_counts[i]})")


plot_success_rates(batch_results2, steering_strategies, Steering_names)
# Out:
# home: Success Rate=50.00% (3/6)
# circle: Success Rate=83.33% (5/6)
# gradient: Success Rate=33.33% (2/6)
# gaussian: Success Rate=66.67% (4/6)
# Inverse Square: Success Rate=66.67% (4/6)
# Exponential: Success Rate=83.33% (5/6)

# %%
# print results
def print_results(batch_results):
    for res, ss in batch_results:
        if res:
            print(
                f"Run (usePheromoneSteering={ss}): Success, duration={res.duration}, success={res.didSucceed}")
        else:
            print(f"Run (usePheromoneSteering={ss}): Failed")

# %%
print_results(batch_results2)
# Out:
# Run (usePheromoneSteering=0): Success, duration=419.2146301269531, success=True
# Run (usePheromoneSteering=1): Success, duration=513.1358642578125, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.14013671875, success=False
# Run (usePheromoneSteering=3): Success, duration=1697.4808349609375, success=True
# Run (usePheromoneSteering=4): Success, duration=2092.74169921875, success=True
# Run (usePheromoneSteering=5): Success, duration=595.333251953125, success=True
# Run (usePheromoneSteering=0): Success, duration=372.9530029296875, success=True
# Run (usePheromoneSteering=1): Success, duration=391.9661865234375, success=True
# Run (usePheromoneSteering=2): Success, duration=628.5658569335938, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.54833984375, success=False
# Run (usePheromoneSteering=4): Success, duration=871.6658935546875, success=True
# Run (usePheromoneSteering=5): Success, duration=5001.02490234375, success=False
# Run (usePheromoneSteering=0): Success, duration=5001.1123046875, success=False
# Run (usePheromoneSteering=1): Success, duration=5000.44482421875, success=False
# Run (usePheromoneSteering=2): Success, duration=5000.3759765625, success=False
# Run (usePheromoneSteering=3): Success, duration=2018.97265625, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.1376953125, success=False
# Run (usePheromoneSteering=5): Success, duration=591.6759033203125, success=True
# Run (usePheromoneSteering=0): Success, duration=312.7364501953125, success=True
# Run (usePheromoneSteering=1): Success, duration=426.3771667480469, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.1552734375, success=False
# Run (usePheromoneSteering=3): Success, duration=5000.1201171875, success=False
# Run (usePheromoneSteering=4): Success, duration=2082.756103515625, success=True
# Run (usePheromoneSteering=5): Success, duration=872.0130615234375, success=True
# Run (usePheromoneSteering=0): Success, duration=5000.080078125, success=False
# Run (usePheromoneSteering=1): Success, duration=424.0507507324219, success=True
# Run (usePheromoneSteering=2): Success, duration=3937.405517578125, success=True
# Run (usePheromoneSteering=3): Success, duration=2343.24609375, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.0419921875, success=False
# Run (usePheromoneSteering=5): Success, duration=855.9443359375, success=True
# Run (usePheromoneSteering=0): Success, duration=5000.09619140625, success=False
# Run (usePheromoneSteering=1): Success, duration=580.3272705078125, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.12158203125, success=False
# Run (usePheromoneSteering=3): Success, duration=2258.63720703125, success=True
# Run (usePheromoneSteering=4): Success, duration=1011.5796508789062, success=True
# Run (usePheromoneSteering=5): Success, duration=556.2532958984375, success=True

# %%
import matplotlib.pyplot as plt


def plot_torus_positions_by_strategy(batch_results, strategy_names=None):
    """
    Plots the torus positions for each strategy in separate graphs.
    Each plot shows the paths for all successful runs of that strategy.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    if strategy_names is None:
        strategy_names = [f"Steering={i}" for i in range(num_strategies)]

    for strategy in range(num_strategies):
        # Collect all successful torus positions for this strategy
        paths = [
            res.torusPositions for res, pher in batch_results
            if pher == strategy and res and hasattr(res, "torusPositions") and res.didSucceed
        ]
        if not paths:
            continue  # Skip if no successful runs

        plt.figure(figsize=(6, 6))
        for path in paths:
            xs = [p.x for p in path]
            ys = [p.y for p in path]
            plt.plot(xs, ys, alpha=0.5)
        plt.title(f"Torus Paths - {strategy_names[strategy]}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.grid(True)
        plt.axis("equal")
        plt.show()

# %%
plot_torus_positions_by_strategy(batch_results2, Steering_names)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_duration_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the durations (time to win) for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect durations for each strategy
    durations_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False):
            durations_by_strategy[strategy].append(res.duration)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(durations_by_strategy, tick_labels=labels)
    plt.ylabel("Duration (seconds)")
    plt.title("Time to Win by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average duration for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            durations_by_strategy[i]) if durations_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Duration = {avg:.2f} seconds")

# Example usage:

# %%
plot_duration_comparison(batch_results2, Steering_names)
# Out:
# home: Average Duration = 368.30 seconds
# circle: Average Duration = 467.17 seconds
# gradient: Average Duration = 2282.99 seconds
# gaussian: Average Duration = 2079.58 seconds
# Inverse Square: Average Duration = 1514.69 seconds
# Exponential: Average Duration = 694.24 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

def compute_path_length(points):
    """Compute total path length from a list of Point objects with x, y attributes."""
    if not points or len(points) < 2:
        return 0
    return sum(
        np.linalg.norm([points[i+1].x - points[i].x, points[i+1].y - points[i].y])
        for i in range(len(points)-1)
    )

def plot_path_length_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the total path length for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect path lengths for each strategy
    path_lengths_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False) and hasattr(res, "torusPositions"):
            path_length = compute_path_length(res.torusPositions)
            path_lengths_by_strategy[strategy].append(path_length)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(path_lengths_by_strategy, tick_labels=labels)
    plt.ylabel("Total Path Length")
    plt.title("Torus Path Length by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average path length for each strategy
    for i in range(num_strategies):
        avg = np.mean(path_lengths_by_strategy[i]) if path_lengths_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Path Length = {avg:.2f}")

# Example usage:

# %%
plot_path_length_comparison(batch_results2, Steering_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_path_length_comparison(batch_results2, Steering_names)
#
# NameError: name 'batch_results2' is not defined
