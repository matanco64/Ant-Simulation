# %%
from sim_tools import run_simulation, SimulationParameters, run_simulations_batch, load_results_from_directory, SimulationData
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

from plotting import (
    plot_success_rates,
    plot_torus_positions_by_strategy,
    plot_duration_comparison,
    compute_path_length,
    plot_path_length_comparison,
    compute_turning_angles,
    compute_average_turning_angle,
    plot_smoothness_comparison
)

# %%
num_sim = 50
steering_strategies = 6
Steering_names = [
    "home",
    "circle",
    "gradient",
    "gaussian",
    "Inverse Square",
    "Exponential",
]

# %%
batch_results = load_results_from_directory("maze_results3")
print(f"Loaded {len(batch_results)} simulation results.")
# Out:
# Loaded 1245 simulation results.

# %%
plot_success_rates(batch_results, steering_strategies, Steering_names, )
# Out:
# home: Success Rate=95.24% (200/210)
# circle: Success Rate=69.23% (144/208)
# gradient: Success Rate=75.85% (157/207)
# gaussian: Success Rate=60.10% (125/208)
# Inverse Square: Success Rate=73.43% (152/207)
# Exponential: Success Rate=57.56% (118/205)

# %%
plot_duration_comparison(batch_results, Steering_names, )
# Out:
# home: Average Duration = 328.00 seconds
# circle: Average Duration = 617.76 seconds
# gradient: Average Duration = 794.33 seconds
# gaussian: Average Duration = 790.87 seconds
# Inverse Square: Average Duration = 702.80 seconds
# Exponential: Average Duration = 819.08 seconds

# %%
plot_path_length_comparison(batch_results, Steering_names)
# Out:
# home: Average Path Length = 108.71
# circle: Average Path Length = 310.99
# gradient: Average Path Length = 391.45
# gaussian: Average Path Length = 408.72
# Inverse Square: Average Path Length = 357.99
# Exponential: Average Path Length = 419.98

# %%
plot_smoothness_comparison(batch_results, Steering_names, )
# Out:
# home: Average Turning Angle = 85.77°
# circle: Average Turning Angle = 109.66°
# gradient: Average Turning Angle = 114.15°
# gaussian: Average Turning Angle = 116.88°
# Inverse Square: Average Turning Angle = 122.52°
# Exponential: Average Turning Angle = 116.05°

# %%
plot_torus_positions_by_strategy(batch_results, Steering_names)
