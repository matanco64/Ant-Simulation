# %%
# 6 strategies, used StraightForceToColony to see if results are different

# adding ApplyColonyPullingForce() to informed as 5 but more runs
# run on maze more time than 7 200 ants detchafter 4f to 10f 	float colonyPullStrength = 4.0f

#changes strategies 0  is always on 
#checking wich combination is the best

# %%
from sim_tools import run_simulation, SimulationParameters
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

# %%
num_sim = 10
steering_strategies = 6

use_pher = [i for i in range(steering_strategies*num_sim)]

batch_results2 = [(run_simulation(SimulationParameters(usePheromoneSteering=pher % steering_strategies), headless=True), pher % steering_strategies)
                 for pher in tqdm(use_pher)]
# Out:
# 100%|██████████| 60/60 [38:54<00:00, 38.91s/it]

# %%
Steering_names = [
    "home",
    "circle + home",
    "gradient + home",
    "gaussian + home",
    "Inverse Square + home",
    "Exponential + home",
]

# %%
def plot_success_rates(batch_results, num_strategies=6, strategy_names=None):
    # Count successes for each strategy
    success_counts = [0] * num_strategies
    total_counts = [0] * num_strategies

    for res, strategy in batch_results:
        if 0 <= strategy < num_strategies:
            total_counts[strategy] += 1
            if res and getattr(res, "didSucceed", False):
                success_counts[strategy] += 1

    # Calculate success rates
    success_rates = [
        (success_counts[i] / total_counts[i]) if total_counts[i] else 0
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), success_rates,
            tick_label=labels, color='skyblue')
    plt.ylabel("Success Rate")
    plt.title("Success Rate by Steering Strategy")
    plt.ylim(0, 1)
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Success Rate={success_rates[i]:.2%} ({success_counts[i]}/{total_counts[i]})")


plot_success_rates(batch_results2, steering_strategies, Steering_names)
# Out:
# home: Success Rate=100.00% (10/10)
# circle + home: Success Rate=100.00% (10/10)
# gradient + home: Success Rate=70.00% (7/10)
# gaussian + home: Success Rate=30.00% (3/10)
# Inverse Square + home: Success Rate=60.00% (6/10)
# Exponential + home: Success Rate=90.00% (9/10)

# %%
# print results
def print_results(batch_results):
    for res, ss in batch_results:
        if res:
            print(
                f"Run (usePheromoneSteering={ss}): Success, duration={res.duration}, success={res.didSucceed}")
        else:
            print(f"Run (usePheromoneSteering={ss}): Failed")

# %%
print_results(batch_results2)
# Out:
# Run (usePheromoneSteering=0): Success, duration=566.1836547851562, success=True
# Run (usePheromoneSteering=1): Success, duration=419.0912170410156, success=True
# Run (usePheromoneSteering=2): Success, duration=556.7545776367188, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.07421875, success=False
# Run (usePheromoneSteering=4): Success, duration=596.8544921875, success=True
# Run (usePheromoneSteering=5): Success, duration=778.78125, success=True
# Run (usePheromoneSteering=0): Success, duration=436.0899963378906, success=True
# Run (usePheromoneSteering=1): Success, duration=437.1850891113281, success=True
# Run (usePheromoneSteering=2): Success, duration=2307.3037109375, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.06982421875, success=False
# Run (usePheromoneSteering=4): Success, duration=5000.0595703125, success=False
# Run (usePheromoneSteering=5): Success, duration=429.16827392578125, success=True
# Run (usePheromoneSteering=0): Success, duration=412.529052734375, success=True
# Run (usePheromoneSteering=1): Success, duration=424.63739013671875, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.02783203125, success=False
# Run (usePheromoneSteering=3): Success, duration=504.1951599121094, success=True
# Run (usePheromoneSteering=4): Success, duration=776.779541015625, success=True
# Run (usePheromoneSteering=5): Success, duration=411.8563232421875, success=True
# Run (usePheromoneSteering=0): Success, duration=413.14019775390625, success=True
# Run (usePheromoneSteering=1): Success, duration=468.5826110839844, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.005859375, success=False
# Run (usePheromoneSteering=3): Success, duration=5000.029296875, success=False
# Run (usePheromoneSteering=4): Success, duration=1236.879150390625, success=True
# Run (usePheromoneSteering=5): Success, duration=500.4573059082031, success=True
# Run (usePheromoneSteering=0): Success, duration=404.4922790527344, success=True
# Run (usePheromoneSteering=1): Success, duration=463.9668884277344, success=True
# Run (usePheromoneSteering=2): Success, duration=2225.499755859375, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.04248046875, success=False
# Run (usePheromoneSteering=4): Success, duration=582.1480712890625, success=True
# Run (usePheromoneSteering=5): Success, duration=5000.01513671875, success=False
# Run (usePheromoneSteering=0): Success, duration=518.5936889648438, success=True
# Run (usePheromoneSteering=1): Success, duration=506.1889343261719, success=True
# Run (usePheromoneSteering=2): Success, duration=792.6905517578125, success=True
# Run (usePheromoneSteering=3): Success, duration=2831.34228515625, success=True
# Run (usePheromoneSteering=4): Success, duration=5000.01220703125, success=False
# Run (usePheromoneSteering=5): Success, duration=1265.5408935546875, success=True
# Run (usePheromoneSteering=0): Success, duration=476.3979797363281, success=True
# Run (usePheromoneSteering=1): Success, duration=446.7000732421875, success=True
# Run (usePheromoneSteering=2): Success, duration=5000.0107421875, success=False
# Run (usePheromoneSteering=3): Success, duration=500.14312744140625, success=True
# Run (usePheromoneSteering=4): Success, duration=4826.6796875, success=True
# Run (usePheromoneSteering=5): Success, duration=1836.2498779296875, success=True
# Run (usePheromoneSteering=0): Success, duration=402.34033203125, success=True
# Run (usePheromoneSteering=1): Success, duration=470.2819519042969, success=True
# Run (usePheromoneSteering=2): Success, duration=852.6143798828125, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.10009765625, success=False
# Run (usePheromoneSteering=4): Success, duration=5000.04052734375, success=False
# Run (usePheromoneSteering=5): Success, duration=1475.6298828125, success=True
# Run (usePheromoneSteering=0): Success, duration=416.2901611328125, success=True
# Run (usePheromoneSteering=1): Success, duration=462.03521728515625, success=True
# Run (usePheromoneSteering=2): Success, duration=616.2960205078125, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.03955078125, success=False
# Run (usePheromoneSteering=4): Success, duration=2565.042724609375, success=True
# Run (usePheromoneSteering=5): Success, duration=466.3951110839844, success=True
# Run (usePheromoneSteering=0): Success, duration=416.8071594238281, success=True
# Run (usePheromoneSteering=1): Success, duration=574.130615234375, success=True
# Run (usePheromoneSteering=2): Success, duration=1299.23681640625, success=True
# Run (usePheromoneSteering=3): Success, duration=5000.0380859375, success=False
# Run (usePheromoneSteering=4): Success, duration=5000.048828125, success=False
# Run (usePheromoneSteering=5): Success, duration=568.2022705078125, success=True

# %%
import matplotlib.pyplot as plt


def plot_torus_positions_by_strategy(batch_results, strategy_names=None):
    """
    Plots the torus positions for each strategy in separate graphs.
    Each plot shows the paths for all successful runs of that strategy.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    if strategy_names is None:
        strategy_names = [f"Steering={i}" for i in range(num_strategies)]

    for strategy in range(num_strategies):
        # Collect all successful torus positions for this strategy
        paths = [
            res.torusPositions for res, pher in batch_results
            if pher == strategy and res and hasattr(res, "torusPositions") and res.didSucceed
        ]
        if not paths:
            continue  # Skip if no successful runs

        plt.figure(figsize=(6, 6))
        for path in paths:
            xs = [p.x for p in path]
            ys = [p.y for p in path]
            plt.plot(xs, ys, alpha=0.5)
        plt.title(f"Torus Paths - {strategy_names[strategy]}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.grid(True)
        plt.axis("equal")
        plt.show()

# %%
plot_torus_positions_by_strategy(batch_results2, Steering_names)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_duration_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the durations (time to win) for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect durations for each strategy
    durations_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False):
            durations_by_strategy[strategy].append(res.duration)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(durations_by_strategy, tick_labels=labels)
    plt.ylabel("Duration (seconds)")
    plt.title("Time to Win by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average duration for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            durations_by_strategy[i]) if durations_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Duration = {avg:.2f} seconds")

# Example usage:

# %%
plot_duration_comparison(batch_results2, Steering_names)
# Out:
# home: Average Duration = 446.29 seconds
# circle + home: Average Duration = 467.28 seconds
# gradient + home: Average Duration = 1235.77 seconds
# gaussian + home: Average Duration = 1278.56 seconds
# Inverse Square + home: Average Duration = 1764.06 seconds
# Exponential + home: Average Duration = 859.14 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np


def compute_path_length(points):
    """Compute total path length from a list of Point objects with x, y attributes."""
    if not points or len(points) < 2:
        return 0
    return sum(
        np.linalg.norm([points[i+1].x - points[i].x,
                       points[i+1].y - points[i].y])
        for i in range(len(points)-1)
    )


def plot_path_length_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the total path length for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect path lengths for each strategy
    path_lengths_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False) and hasattr(res, "torusPositions"):
            path_length = compute_path_length(res.torusPositions)
            path_lengths_by_strategy[strategy].append(path_length)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(path_lengths_by_strategy, tick_labels=labels)
    plt.ylabel("Total Path Length")
    plt.title("Torus Path Length by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average path length for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            path_lengths_by_strategy[i]) if path_lengths_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Path Length = {avg:.2f}")

# Example usage:

# %%
plot_path_length_comparison(batch_results2, Steering_names)
# Out:
# home: Average Path Length = 108.90
# circle + home: Average Path Length = 128.15
# gradient + home: Average Path Length = 373.15
# gaussian + home: Average Path Length = 302.91
# Inverse Square + home: Average Path Length = 408.12
# Exponential + home: Average Path Length = 241.02

# %%
import numpy as np
import matplotlib.pyplot as plt


def compute_average_turning_angle(points):
    """Compute the average turning angle (in degrees) for a path of Point objects."""
    if not points or len(points) < 3:
        return 0
    angles = []
    for i in range(1, len(points)-1):
        v1 = np.array([points[i].x - points[i-1].x,
                      points[i].y - points[i-1].y])
        v2 = np.array([points[i+1].x - points[i].x,
                      points[i+1].y - points[i].y])
        if np.linalg.norm(v1) == 0 or np.linalg.norm(v2) == 0:
            continue
        cos_angle = np.clip(
            np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)), -1, 1)
        angle = np.arccos(cos_angle)
        angles.append(np.degrees(angle))
    return np.mean(angles) if angles else 0


def plot_smoothness_comparison(batch_results, strategy_names=None):
    """
    Plots a bar chart comparing the average turning angle (smoothness) for each strategy.
    Only successful runs are included.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    smoothness_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False) and hasattr(res, "torusPositions"):
            avg_angle = compute_average_turning_angle(res.torusPositions)
            smoothness_by_strategy[strategy].append(avg_angle)

    # Compute mean smoothness for each strategy
    mean_smoothness = [
        np.mean(smoothness_by_strategy[i]) if smoothness_by_strategy[i] else float(
            'nan')
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), mean_smoothness,
            tick_label=labels, color='purple')
    plt.ylabel("Average Turning Angle (degrees)")
    plt.title("Route Smoothness by Strategy (Lower is Smoother)")
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Average Turning Angle = {mean_smoothness[i]:.2f}°")

# Example usage:
# plot_smoothness_comparison(batch_results2, Steering_names)
