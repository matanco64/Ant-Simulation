# %%
from sim_tools import run_simulation, SimulationParameters
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

# %%
num_sim = 10
steering_strategies = 6

use_pher = [i for i in range(steering_strategies*num_sim)]

batch_results2 = [(run_simulation(SimulationParameters(usePheromoneSteering=pher % steering_strategies)), pher % steering_strategies)
                 for pher in tqdm(use_pher)]
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# 100%|██████████| 60/60 [12:32<00:00, 12.54s/it]

# %%
Steering_names = [
    "home",
    "circle",
    "gradient",
    "gaussian",
    "Inverse Square",
    "Exponential",
]

# %%
def plot_success_rates(batch_results, num_strategies=6, strategy_names=None):
    # Count successes for each strategy
    success_counts = [0] * num_strategies
    total_counts = [0] * num_strategies

    for res, strategy in batch_results:
        if 0 <= strategy < num_strategies:
            total_counts[strategy] += 1
            if res and getattr(res, "didSucceed", False):
                success_counts[strategy] += 1

    # Calculate success rates
    success_rates = [
        (success_counts[i] / total_counts[i]) if total_counts[i] else 0
        for i in range(num_strategies)
    ]

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.bar(range(num_strategies), success_rates,
            tick_label=labels, color='skyblue')
    plt.ylabel("Success Rate")
    plt.title("Success Rate by Steering Strategy")
    plt.ylim(0, 1)
    plt.grid(axis='y')
    plt.show()

    # Print summary
    for i in range(num_strategies):
        print(
            f"{labels[i]}: Success Rate={success_rates[i]:.2%} ({success_counts[i]}/{total_counts[i]})")


plot_success_rates(batch_results2, steering_strategies, Steering_names)
# Out:
# home: Success Rate=0.00% (0/10)
# circle: Success Rate=0.00% (0/10)
# gradient: Success Rate=10.00% (1/10)
# gaussian: Success Rate=0.00% (0/10)
# Inverse Square: Success Rate=0.00% (0/10)
# Exponential: Success Rate=0.00% (0/10)

# %%
# print results
def print_results(batch_results):
    for res, ss in batch_results:
        if res:
            print(
                f"Run (usePheromoneSteering={ss}): Success, duration={res.duration}, success={res.didSucceed}")
        else:
            print(f"Run (usePheromoneSteering={ss}): Failed")
# Out:
# Run (usePheromoneSteering=0): Success, duration=600.0494995117188, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0767211914062, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0535278320312, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0005493164062, success=False
# Run (usePheromoneSteering=4): Success, duration=600.05615234375, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0117797851562, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0064697265625, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0867309570312, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0736694335938, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0579223632812, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0614624023438, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0433959960938, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0689086914062, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0234375, success=False
# Run (usePheromoneSteering=2): Success, duration=600.02294921875, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0062255859375, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0216064453125, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0064697265625, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0399169921875, success=False
# Run (usePheromoneSteering=1): Success, duration=600.009765625, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0685424804688, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0274047851562, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0281982421875, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0226440429688, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0657958984375, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0211181640625, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0282592773438, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0469360351562, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0659790039062, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0046997070312, success=False
# Run (usePheromoneSteering=0): Success, duration=600.05908203125, success=False
# Run (usePheromoneSteering=1): Success, duration=94.35125732421875, success=True
# Run (usePheromoneSteering=2): Success, duration=600.0658569335938, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0359497070312, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0350341796875, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0670776367188, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0010986328125, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0471801757812, success=False
# Run (usePheromoneSteering=2): Success, duration=203.55613708496094, success=True
# Run (usePheromoneSteering=3): Success, duration=600.0502319335938, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0233764648438, success=False
# Run (usePheromoneSteering=5): Success, duration=600.064697265625, success=False

# %%
print_results(batch_results2)
# Out:
# Run (usePheromoneSteering=0): Success, duration=600.0494995117188, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0767211914062, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0535278320312, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0005493164062, success=False
# Run (usePheromoneSteering=4): Success, duration=600.05615234375, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0117797851562, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0064697265625, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0867309570312, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0736694335938, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0579223632812, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0614624023438, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0433959960938, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0689086914062, success=False
# Run (usePheromoneSteering=1): Success, duration=600.0234375, success=False
# Run (usePheromoneSteering=2): Success, duration=600.02294921875, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0062255859375, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0216064453125, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0064697265625, success=False
# Run (usePheromoneSteering=0): Success, duration=600.0399169921875, success=False
# Run (usePheromoneSteering=1): Success, duration=600.009765625, success=False
# Run (usePheromoneSteering=2): Success, duration=600.0685424804688, success=False
# Run (usePheromoneSteering=3): Success, duration=600.0274047851562, success=False
# Run (usePheromoneSteering=4): Success, duration=600.0281982421875, success=False
# Run (usePheromoneSteering=5): Success, duration=600.0226440429688, success=False

# %%
import matplotlib.pyplot as plt


def plot_torus_positions_by_strategy(batch_results, strategy_names=None):
    """
    Plots the torus positions for each strategy in separate graphs.
    Each plot shows the paths for all successful runs of that strategy.
    """
    num_strategies = max(pher for _, pher in batch_results) + 1
    if strategy_names is None:
        strategy_names = [f"Steering={i}" for i in range(num_strategies)]

    for strategy in range(num_strategies):
        # Collect all successful torus positions for this strategy
        paths = [
            res.torusPositions for res, pher in batch_results
            if pher == strategy and res and hasattr(res, "torusPositions") and res.didSucceed
        ]
        if not paths:
            continue  # Skip if no successful runs

        plt.figure(figsize=(6, 6))
        for path in paths:
            xs = [p.x for p in path]
            ys = [p.y for p in path]
            plt.plot(xs, ys, alpha=0.5)
        plt.title(f"Torus Paths - {strategy_names[strategy]}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.grid(True)
        plt.axis("equal")
        plt.show()

# %%
plot_torus_positions_by_strategy(batch_results2, Steering_names)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_duration_comparison(batch_results, strategy_names=None):
    """
    Plots a boxplot comparing the durations (time to win) for each strategy.
    Only successful runs are included.
    """
    # Determine number of strategies
    num_strategies = max(pher for _, pher in batch_results) + 1

    # Collect durations for each strategy
    durations_by_strategy = [[] for _ in range(num_strategies)]
    for res, strategy in batch_results:
        if res and getattr(res, "didSucceed", False):
            durations_by_strategy[strategy].append(res.duration)

    # Prepare labels
    if strategy_names is None:
        labels = [f"Steering={i}" for i in range(num_strategies)]
    else:
        labels = [strategy_names[i] if i < len(
            strategy_names) else f"Steering={i}" for i in range(num_strategies)]

    # Plot boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(durations_by_strategy, tick_labels=labels)
    plt.ylabel("Duration (seconds)")
    plt.title("Time to Win by Strategy (Successful Runs Only)")
    plt.grid(True)
    plt.show()

    # Print average duration for each strategy
    for i in range(num_strategies):
        avg = np.mean(
            durations_by_strategy[i]) if durations_by_strategy[i] else float('nan')
        print(f"{labels[i]}: Average Duration = {avg:.2f} seconds")

# Example usage:

# %%
plot_duration_comparison(batch_results2, Steering_names)
# Out:
# home: Average Duration = nan seconds
# circle: Average Duration = nan seconds
# gradient: Average Duration = 228.63 seconds
# gaussian: Average Duration = nan seconds
# Inverse Square: Average Duration = nan seconds
# Exponential: Average Duration = nan seconds
